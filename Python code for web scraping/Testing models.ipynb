# %%
import pandas as pd
file = pd.read_csv("final.csv")
proc_file = file.drop(columns = ["Unnamed: 0"]).loc[file["town"] == 'SENGKANG'].copy()

# %%
# For Sengkang only
# Out:
#        month      town  flat_type storey_range  floor_area_sqm  \
# 4115      11  SENGKANG     4 ROOM     10 TO 12             101
# 4116      11  SENGKANG     4 ROOM     01 TO 03             100
# 4117      11  SENGKANG     4 ROOM     04 TO 06             100
# 4118      11  SENGKANG     4 ROOM     10 TO 12              92
# 4119      11  SENGKANG     4 ROOM     10 TO 12              90
# 4120      11  SENGKANG     4 ROOM     04 TO 06              90
# 4121      11  SENGKANG     4 ROOM     16 TO 18              90
# 4122      11  SENGKANG     4 ROOM     07 TO 09              90
# 4123      11  SENGKANG     4 ROOM     10 TO 12              90
# 4124      11  SENGKANG     4 ROOM     07 TO 09              96
# 4125      11  SENGKANG     4 ROOM     10 TO 12              96
# 4126      11  SENGKANG  EXECUTIVE     10 TO 12             141
# 5110       2  SENGKANG     4 ROOM     13 TO 15             102
# 5111       2  SENGKANG     4 ROOM     01 TO 03             102
# ...
